# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.rcParams['figure.figsize'] = (8.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
img=plt.imread('Einstein.jpg')

# %%
plt.imshow(img);

# %%
gray_img = np.mean(img, axis=2)/255.0
plt.imshow(gray_img);

# %%
def conv_single_step(img_slice,filter):
    output=np.sum(np.multiply(img_slice,filter))
    return output

# %%
def forward_pass(img,W):
    height,width=img.shape
    Z=np.zeros((height-2,width-2))   
    for h in range(height-2):
        vert_start=h
        vert_end=vert_start+3
        for w in range(width-2):
            horiz_start=w
            horiz_end=horiz_start+3
            
            img_slice=img[vert_start:vert_end,horiz_start:horiz_end]
            Z[h,w]=conv_single_step(img_slice,W)
    return Z

# %%
def visualize(original_img,filtered_img):
    fig, ax = plt.subplots(1, 2)
    ax[0].set_title('Original Image')
    ax[0].axis('off')
    ax[0].imshow(original_img)
    ax[1].set_title('Filtered Image')
    ax[1].axis('off')
    ax[1].imshow(filtered_img)

# %% [markdown]
# # Q.1

# %%
#filter1 c=1
W1=np.array([0,0,1,
            0,0,0,
            0,0,0]).reshape(3,3)
W1
# Out:
# array([[0, 0, 1],
#        [0, 0, 0],
#        [0, 0, 0]])

# %%
filtered_img=forward_pass(gray_image,W1)

# %%
visualize(gray_image,filtered_img)

# %%
#filter2 
W2=np.array([0,0,0,
            1,0,0,
            0,0,0]).reshape(3,3)
W2
# Out:
# array([[0, 0, 0],
#        [1, 0, 0],
#        [0, 0, 0]])

# %%
filtered_img=forward_pass(gray_image,W2)
visualize(gray_image,filtered_img)

# %%
#filter3
W3=np.array([0,0,0,
            0,1,0,
            0,0,0]).reshape(3,3)
W3
# Out:
# array([[0, 0, 0],
#        [0, 1, 0],
#        [0, 0, 0]])

# %%
filtered_img=forward_pass(gray_image,W3)
visualize(gray_image,filtered_img)

# %%
W4=np.array([0,0,0,
            0,0,1,
            0,0,0]).reshape(3,3)
W4
# Out:
# array([[0, 0, 0],
#        [0, 0, 1],
#        [0, 0, 0]])

# %%
filtered_img=forward_pass(gray_image,W4)
visualize(gray_image,filtered_img)

# %%
W5=np.array([0,0,0,
            0,0,0,
            1,0,0]).reshape(3,3)
W5
# Out:
# array([[0, 0, 0],
#        [0, 0, 0],
#        [1, 0, 0]])

# %%
filtered_img=forward_pass(gray_image,W5)
visualize(gray_image,filtered_img)

# %% [markdown]
# # Q2

# %%
#filter1
W6=np.array([1,0,-1,
            2,0,-2,
            1,0,-1]).reshape(3,3)
W6
# Out:
# array([[ 1,  0, -1],
#        [ 2,  0, -2],
#        [ 1,  0, -1]])

# %%
filtered_img_6=forward_pass(gray_image,W6)
visualize(gray_image,filtered_img)

# %%
visualize(gray_image[1000:1500,1000:1500],filtered_img_6[998:1498,998:1498])

# %%
W7=np.array([1,2,1,
            0,0,0,
            -1,-2,-1]).reshape(3,3)
W7
# Out:
# array([[ 1,  2,  1],
#        [ 0,  0,  0],
#        [-1, -2, -1]])

# %%
filtered_img=forward_pass(gray_image,W7)
visualize(gray_image,filtered_img)

# %% [markdown]
# # Q3

# %%
visualize(gray_image[1000:1500,1000:1500],filtered_img[998:1498,998:1498])

# %% [markdown]
# # Q3

# %%
#Gaussian filter
W8=np.array([1,1,1,
            1,1,1,
            1,1,1]).reshape(3,3)
W8=W8*(1/9)
W8
# Out:
# array([[0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111],
#        [0.11111111, 0.11111111, 0.11111111]])

# %%
filtered_img_8=forward_pass(gray_image,W8)
visualize(gray_image,filtered_img_8)

# %%
visualize(gray_image[1000:1500,1000:1500],filtered_img_8[998:1498,998:1498])
